# %% [markdown]
# <a href="https://colab.research.google.com/github/arssite/Datalysis/blob/main/Drowsiness_Cnn_Model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import cv2
from tensorflow.keras.layers import Input, Conv2D, BatchNormalization, Dropout, Flatten, Dense, MaxPool2D
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.initializers import glorot_uniform
from tensorflow.keras.optimizers import Adam, SGD
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns
from tensorflow.keras.regularizers import l2
import tensorflow as tf
import pandas as pd
from imutils.face_utils import FaceAligner
from imutils.face_utils import rect_to_bb
import imutils
import dlib

# %%
# !wget https://cainvas-static.s3.amazonaws.com/media/user_data/cainvas-admin/driver_drowsiness_detection_modified.zip
# !unzip -qo driver_drowsiness_detection_modified.zip
# Out:
# --2024-03-02 09:29:16--  https://cainvas-static.s3.amazonaws.com/media/user_data/cainvas-admin/driver_drowsiness_detection_modified.zip
# Resolving cainvas-static.s3.amazonaws.com (cainvas-static.s3.amazonaws.com)... 52.219.156.183, 52.219.156.171, 52.219.156.207, ...
# Connecting to cainvas-static.s3.amazonaws.com (cainvas-static.s3.amazonaws.com)|52.219.156.183|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 127436131 (122M) [application/x-zip-compressed]
# Saving to: ‘driver_drowsiness_detection_modified.zip’
#
# driver_drowsiness_d 100%[===================>] 121.53M  13.0MB/s    in 11s
#
# 2024-03-02 09:29:28 (11.0 MB/s) - ‘driver_drowsiness_detection_modified.zip’ saved [127436131/127436131]

# %%
data = np.load('driver_drowsiness_detection/dataset_compressed.npz', allow_pickle=True)
X = data['arr_0']
Y = data['arr_1']

X = list(X)
Y = list(Y)
print(len(X))
print(len(Y))
# Out:
# 1452
# 1452

# %%
for i in range(len(X)):
    img = X[i]
    img = cv2.resize(img, (32, 32))
    X[i] = img

print(len(X))
print(X[0].shape)
# Out:
# 1452
# (32, 32, 3)

# %%
label_encoder = LabelEncoder()
Y = label_encoder.fit_transform(Y)
print(Y.shape)
print(Y[0])
print(set(Y))
# Out:
# (1452,)
# 0
# {0, 1}

# %%
X = np.array(X)
Y = np.array(Y)
print(X.shape)
print(Y.shape)
# Out:
# (1452, 32, 32, 3)
# (1452,)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2)

# %%
print(X_train.shape)
print(Y_train.shape)
print(X_test.shape)
print(Y_test.shape)

Y_train = to_categorical(Y_train)
Y_test = to_categorical(Y_test)

print(X_train.shape)
print(Y_train.shape)
print(X_test.shape)
print(Y_test.shape)
# Out:
# (1161, 32, 32, 3)
# (1161,)
# (291, 32, 32, 3)
# (291,)
# (1161, 32, 32, 3)
# (1161, 2)
# (291, 32, 32, 3)
# (291, 2)

# %%
figure1 = plt.figure(figsize=(5, 5))
idx_closed = np.where(Y==0)
img_closed = X[idx_closed[0][0]]
plt.imshow(img_closed)
plt.title('Image of Closed Eye representing Driver is sleeping')
plt.axis('off')
plt.show()

figure2 = plt.figure(figsize=(5, 5))
idx_open = np.where(Y==1)
img_open = X[idx_open[0][0]]
plt.imshow(img_open)
plt.title('Image of Open Eye representing Driver is not sleeping')
plt.axis('off')
plt.show()

# %%
unique_train, count = np.unique(Y_train, return_counts=True)
'''plt.figure(figsize=(20, 10))
sns.barplot(unique_train, count).set_title("Number of training images per category:")
plt.show()'''
df = pd.DataFrame({"category": unique_train, "count": count})
plt.figure(figsize=(20, 10))
sns.barplot(data=df, x="category", y="count").set_title("Number of training images per category:")
plt.show()

# %%
def driver_drowsiness_detection_model(input_shape=(32, 32, 3)):
    model = Sequential()
    model.add(Input(shape=input_shape))
    model.add(Conv2D(32, (3, 3), padding='same', strides=(1, 1), name='conv1', activation='relu',
                     kernel_initializer=glorot_uniform(seed=0)))
    model.add(BatchNormalization())
    model.add(Conv2D(32, (3, 3), padding='same', strides=(1, 1), name='conv2', activation='relu',
                     kernel_initializer=glorot_uniform(seed=0)))
    model.add(BatchNormalization())
    model.add(Dropout(0.2))
    model.add(MaxPool2D((2, 2), strides=(2, 2)))

    model.add(Conv2D(64, (3, 3), padding='same', strides=(1, 1), name='conv3', activation='relu',
                     kernel_initializer=glorot_uniform(seed=0)))
    model.add(BatchNormalization())
    model.add(MaxPool2D((2, 2), strides=(2, 2)))
    model.add(Conv2D(64, (3, 3), padding='same', strides=(1, 1), name='conv4', activation='relu',
                     kernel_initializer=glorot_uniform(seed=0)))
    model.add(BatchNormalization())
    model.add(Dropout(0.3))
    model.add(MaxPool2D((2, 2), strides=(2, 2)))

    model.add(Conv2D(64, (3, 3), padding='same', strides=(1, 1), name='conv5', activation='relu',
                     kernel_initializer=glorot_uniform(seed=0)))
    model.add(BatchNormalization())
    model.add(Conv2D(64, (3, 3), padding='same', strides=(1, 1), name='conv6', activation='relu',
                     kernel_initializer=glorot_uniform(seed=0)))
    model.add(BatchNormalization())
    model.add(Conv2D(64, (3, 3), padding='same', strides=(1, 1), name='conv7', activation='relu',
                     kernel_initializer=glorot_uniform(seed=0)))
    model.add(BatchNormalization())
    model.add(Dropout(0.4))
    model.add(MaxPool2D((2, 2), strides=(2, 2)))


    model.add(Flatten())
    model.add(Dense(128, activation='relu', kernel_initializer=glorot_uniform(seed=0), name='fc1'))
    model.add(Dropout(0.5))
    model.add(Dense(128, activation='relu', kernel_initializer=glorot_uniform(seed=0), name='fc2'))
    model.add(Dropout(0.5))
    model.add(Dense(2, activation='softmax', kernel_initializer=glorot_uniform(seed=0), name='fc3'))

    optimizer = Adam(0.0001)
    model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
    return model

# %%
model= driver_drowsiness_detection_model(input_shape=(32, 32, 3))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1 (Conv2D)              (None, 32, 32, 32)        896
#
#  batch_normalization (Batch  (None, 32, 32, 32)        128
#  Normalization)
#
#  conv2 (Conv2D)              (None, 32, 32, 32)        9248
#
#  batch_normalization_1 (Bat  (None, 32, 32, 32)        128
#  chNormalization)
#
#  dropout (Dropout)           (None, 32, 32, 32)        0
#
#  max_pooling2d (MaxPooling2  (None, 16, 16, 32)        0
#  D)
#
#  conv3 (Conv2D)              (None, 16, 16, 64)        18496
#
#  batch_normalization_2 (Bat  (None, 16, 16, 64)        256
#  chNormalization)
#
#  max_pooling2d_1 (MaxPoolin  (None, 8, 8, 64)          0
#  g2D)
#
#  conv4 (Conv2D)              (None, 8, 8, 64)          36928
#
#  batch_normalization_3 (Bat  (None, 8, 8, 64)          256
#  chNormalization)
#
#  dropout_1 (Dropout)         (None, 8, 8, 64)          0
#
#  max_pooling2d_2 (MaxPoolin  (None, 4, 4, 64)          0
#  g2D)
#
#  conv5 (Conv2D)              (None, 4, 4, 64)          36928
#
#  batch_normalization_4 (Bat  (None, 4, 4, 64)          256
#  chNormalization)
#
#  conv6 (Conv2D)              (None, 4, 4, 64)          36928
#
#  batch_normalization_5 (Bat  (None, 4, 4, 64)          256
#  chNormalization)
#
#  conv7 (Conv2D)              (None, 4, 4, 64)          36928
#
#  batch_normalization_6 (Bat  (None, 4, 4, 64)          256
#  chNormalization)
#
#  dropout_2 (Dropout)         (None, 4, 4, 64)          0
#
#  max_pooling2d_3 (MaxPoolin  (None, 2, 2, 64)          0
#  g2D)
#
#  flatten (Flatten)           (None, 256)               0
#
#  fc1 (Dense)                 (None, 128)               32896
#
#  dropout_3 (Dropout)         (None, 128)               0
#
#  fc2 (Dense)                 (None, 128)               16512
#
#  dropout_4 (Dropout)         (None, 128)               0
#
#  fc3 (Dense)                 (None, 2)                 258
#
# =================================================================
# Total params: 227554 (888.88 KB)
# Trainable params: 226786 (885.88 KB)
# Non-trainable params: 768 (3.00 KB)
# _________________________________________________________________

# %%
aug = ImageDataGenerator(rotation_range=20, zoom_range=0.2, horizontal_flip=True)
hist = model.fit(aug.flow(X_train, Y_train, batch_size=128), batch_size=128, epochs=200, validation_data=(X_test, Y_test))
# Out:
# Epoch 1/200
# 10/10 [==============================] - 12s 746ms/step - loss: 1.3541 - accuracy: 0.5013 - val_loss: 0.7075 - val_accuracy: 0.4983
# Epoch 2/200
# 10/10 [==============================] - 8s 898ms/step - loss: 1.2853 - accuracy: 0.5426 - val_loss: 0.6936 - val_accuracy: 0.5017
# Epoch 3/200
# 10/10 [==============================] - 7s 682ms/step - loss: 1.0693 - accuracy: 0.5616 - val_loss: 0.6696 - val_accuracy: 0.5430
# Epoch 4/200
# 10/10 [==============================] - 8s 891ms/step - loss: 0.9360 - accuracy: 0.5891 - val_loss: 0.6443 - val_accuracy: 0.6014
# Epoch 5/200
# 10/10 [==============================] - 6s 629ms/step - loss: 0.9515 - accuracy: 0.5831 - val_loss: 0.6294 - val_accuracy: 0.6254
# Epoch 6/200
# 10/10 [==============================] - 8s 788ms/step - loss: 0.8701 - accuracy: 0.6158 - val_loss: 0.6209 - val_accuracy: 0.6838
# Epoch 7/200
# 10/10 [==============================] - 8s 832ms/step - loss: 0.8013 - accuracy: 0.6210 - val_loss: 0.6132 - val_accuracy: 0.6976
# Epoch 8/200
# 10/10 [==============================] - 7s 672ms/step - loss: 0.7539 - accuracy: 0.6391 - val_loss: 0.6033 - val_accuracy: 0.7113
# Epoch 9/200
# 10/10 [==============================] - 8s 884ms/step - loss: 0.7574 - accuracy: 0.6288 - val_loss: 0.5957 - val_accuracy: 0.7285
# Epoch 10/200
# 10/10 [==============================] - 7s 648ms/step - loss: 0.7945 - accuracy: 0.6245 - val_loss: 0.5875 - val_accuracy: 0.7182
# Epoch 11/200
# 10/10 [==============================] - 7s 665ms/step - loss: 0.6968 - accuracy: 0.6503 - val_loss: 0.5786 - val_accuracy: 0.7182
# Epoch 12/200
# 10/10 [==============================] - 7s 639ms/step - loss: 0.6507 - accuracy: 0.6658 - val_loss: 0.5726 - val_accuracy: 0.7113
# Epoch 13/200
# 10/10 [==============================] - 7s 774ms/step - loss: 0.6603 - accuracy: 0.6761 - val_loss: 0.5658 - val_accuracy: 0.7079
# Epoch 14/200
# 10/10 [==============================] - 8s 778ms/step - loss: 0.6597 - accuracy: 0.6684 - val_loss: 0.5576 - val_accuracy: 0.7182
# Epoch 15/200
# 10/10 [==============================] - 7s 638ms/step - loss: 0.6632 - accuracy: 0.6658 - val_loss: 0.5457 - val_accuracy: 0.7320
# Epoch 16/200
# 10/10 [==============================] - 7s 742ms/step - loss: 0.5956 - accuracy: 0.7390 - val_loss: 0.5353 - val_accuracy: 0.7423
# Epoch 17/200
# 10/10 [==============================] - 7s 670ms/step - loss: 0.5900 - accuracy: 0.7201 - val_loss: 0.5233 - val_accuracy: 0.7526
# Epoch 18/200
# 10/10 [==============================] - 8s 816ms/step - loss: 0.5444 - accuracy: 0.7356 - val_loss: 0.5099 - val_accuracy: 0.7663
# Epoch 19/200
# 10/10 [==============================] - 7s 690ms/step - loss: 0.5807 - accuracy: 0.7270 - val_loss: 0.4956 - val_accuracy: 0.7766
# Epoch 20/200
# 10/10 [==============================] - 7s 666ms/step - loss: 0.5540 - accuracy: 0.7218 - val_loss: 0.4807 - val_accuracy: 0.7801
# Epoch 21/200
# 10/10 [==============================] - 8s 794ms/step - loss: 0.5702 - accuracy: 0.7382 - val_loss: 0.4663 - val_accuracy: 0.7973
# Epoch 22/200
# 10/10 [==============================] - 6s 632ms/step - loss: 0.5189 - accuracy: 0.7416 - val_loss: 0.4521 - val_accuracy: 0.7973
# Epoch 23/200
# 10/10 [==============================] - 8s 806ms/step - loss: 0.5210 - accuracy: 0.7606 - val_loss: 0.4365 - val_accuracy: 0.8007
# Epoch 24/200
# 10/10 [==============================] - 7s 653ms/step - loss: 0.5249 - accuracy: 0.7537 - val_loss: 0.4211 - val_accuracy: 0.8041
# Epoch 25/200
# 10/10 [==============================] - 6s 635ms/step - loss: 0.5105 - accuracy: 0.7709 - val_loss: 0.4060 - val_accuracy: 0.8213
# Epoch 26/200
# 10/10 [==============================] - 8s 716ms/step - loss: 0.4894 - accuracy: 0.7726 - val_loss: 0.3906 - val_accuracy: 0.8316
# Epoch 27/200
# 10/10 [==============================] - 8s 763ms/step - loss: 0.4829 - accuracy: 0.7907 - val_loss: 0.3748 - val_accuracy: 0.8351
# Epoch 28/200
# 10/10 [==============================] - 6s 629ms/step - loss: 0.4510 - accuracy: 0.8071 - val_loss: 0.3571 - val_accuracy: 0.8488
# Epoch 29/200
# 10/10 [==============================] - 8s 798ms/step - loss: 0.4768 - accuracy: 0.8105 - val_loss: 0.3427 - val_accuracy: 0.8488
# Epoch 30/200
# 10/10 [==============================] - 7s 675ms/step - loss: 0.4381 - accuracy: 0.8148 - val_loss: 0.3315 - val_accuracy: 0.8591
# Epoch 31/200
# 10/10 [==============================] - 7s 664ms/step - loss: 0.4518 - accuracy: 0.8200 - val_loss: 0.3208 - val_accuracy: 0.8557
# Epoch 32/200
# 10/10 [==============================] - 6s 635ms/step - loss: 0.4037 - accuracy: 0.8277 - val_loss: 0.3105 - val_accuracy: 0.8660
# Epoch 33/200
# 10/10 [==============================] - 7s 755ms/step - loss: 0.4171 - accuracy: 0.8122 - val_loss: 0.2991 - val_accuracy: 0.8694
# Epoch 34/200
# 10/10 [==============================] - 8s 799ms/step - loss: 0.3924 - accuracy: 0.8363 - val_loss: 0.2876 - val_accuracy: 0.8763
# Epoch 35/200
# 10/10 [==============================] - 6s 629ms/step - loss: 0.3849 - accuracy: 0.8346 - val_loss: 0.2785 - val_accuracy: 0.8900
# Epoch 36/200
# 10/10 [==============================] - 8s 737ms/step - loss: 0.3797 - accuracy: 0.8363 - val_loss: 0.2664 - val_accuracy: 0.8935
# Epoch 37/200
# 10/10 [==============================] - 7s 679ms/step - loss: 0.3485 - accuracy: 0.8484 - val_loss: 0.2561 - val_accuracy: 0.8969
# Epoch 38/200
# 10/10 [==============================] - 7s 663ms/step - loss: 0.3613 - accuracy: 0.8432 - val_loss: 0.2469 - val_accuracy: 0.9038
# Epoch 39/200
# 10/10 [==============================] - 8s 886ms/step - loss: 0.3637 - accuracy: 0.8570 - val_loss: 0.2407 - val_accuracy: 0.9003
# Epoch 40/200
# 10/10 [==============================] - 8s 823ms/step - loss: 0.3508 - accuracy: 0.8665 - val_loss: 0.2325 - val_accuracy: 0.9107
# Epoch 41/200
# 10/10 [==============================] - 7s 662ms/step - loss: 0.2882 - accuracy: 0.8854 - val_loss: 0.2215 - val_accuracy: 0.9107
# Epoch 42/200
# 10/10 [==============================] - 8s 812ms/step - loss: 0.2977 - accuracy: 0.8777 - val_loss: 0.2123 - val_accuracy: 0.9175
# Epoch 43/200
# 10/10 [==============================] - 7s 653ms/step - loss: 0.3209 - accuracy: 0.8622 - val_loss: 0.2054 - val_accuracy: 0.9175
# Epoch 44/200
# 10/10 [==============================] - 8s 724ms/step - loss: 0.2852 - accuracy: 0.8837 - val_loss: 0.2011 - val_accuracy: 0.9175
# Epoch 45/200
# 10/10 [==============================] - 8s 763ms/step - loss: 0.2775 - accuracy: 0.8846 - val_loss: 0.1919 - val_accuracy: 0.9175
# Epoch 46/200
# 10/10 [==============================] - 7s 694ms/step - loss: 0.2961 - accuracy: 0.8846 - val_loss: 0.1862 - val_accuracy: 0.9210
# Epoch 47/200
# 10/10 [==============================] - 7s 664ms/step - loss: 0.2822 - accuracy: 0.8923 - val_loss: 0.1826 - val_accuracy: 0.9278
# Epoch 48/200
# 10/10 [==============================] - 8s 749ms/step - loss: 0.2753 - accuracy: 0.8975 - val_loss: 0.1785 - val_accuracy: 0.9175
# Epoch 49/200
# 10/10 [==============================] - 7s 666ms/step - loss: 0.2700 - accuracy: 0.9113 - val_loss: 0.1770 - val_accuracy: 0.9175
# Epoch 50/200
# 10/10 [==============================] - 6s 624ms/step - loss: 0.2548 - accuracy: 0.8906 - val_loss: 0.1752 - val_accuracy: 0.9244
# Epoch 51/200
# 10/10 [==============================] - 6s 630ms/step - loss: 0.2126 - accuracy: 0.9078 - val_loss: 0.1774 - val_accuracy: 0.9210
# Epoch 52/200
# 10/10 [==============================] - 7s 751ms/step - loss: 0.2283 - accuracy: 0.9104 - val_loss: 0.1818 - val_accuracy: 0.9244
# Epoch 53/200
# 10/10 [==============================] - 8s 755ms/step - loss: 0.2195 - accuracy: 0.9156 - val_loss: 0.1743 - val_accuracy: 0.9313
# Epoch 54/200
# 10/10 [==============================] - 7s 670ms/step - loss: 0.2532 - accuracy: 0.9182 - val_loss: 0.1671 - val_accuracy: 0.9313
# Epoch 55/200
# 10/10 [==============================] - 6s 622ms/step - loss: 0.2193 - accuracy: 0.9121 - val_loss: 0.1615 - val_accuracy: 0.9313
# Epoch 56/200
# 10/10 [==============================] - 8s 770ms/step - loss: 0.2335 - accuracy: 0.9104 - val_loss: 0.1602 - val_accuracy: 0.9278
# Epoch 57/200
# 10/10 [==============================] - 8s 774ms/step - loss: 0.2041 - accuracy: 0.9233 - val_loss: 0.1589 - val_accuracy: 0.9313
# Epoch 58/200
# 10/10 [==============================] - 7s 675ms/step - loss: 0.2372 - accuracy: 0.9173 - val_loss: 0.1631 - val_accuracy: 0.9347
# Epoch 59/200
# 10/10 [==============================] - 7s 666ms/step - loss: 0.1934 - accuracy: 0.9190 - val_loss: 0.1603 - val_accuracy: 0.9416
# Epoch 60/200
# 10/10 [==============================] - 7s 725ms/step - loss: 0.2072 - accuracy: 0.9311 - val_loss: 0.1568 - val_accuracy: 0.9313
# Epoch 61/200
# 10/10 [==============================] - 7s 667ms/step - loss: 0.1627 - accuracy: 0.9328 - val_loss: 0.1513 - val_accuracy: 0.9381
# Epoch 62/200
# 10/10 [==============================] - 8s 768ms/step - loss: 0.1650 - accuracy: 0.9388 - val_loss: 0.1486 - val_accuracy: 0.9416
# Epoch 63/200
# 10/10 [==============================] - 8s 760ms/step - loss: 0.1677 - accuracy: 0.9388 - val_loss: 0.1482 - val_accuracy: 0.9347
# Epoch 64/200
# 10/10 [==============================] - 7s 670ms/step - loss: 0.1850 - accuracy: 0.9251 - val_loss: 0.1520 - val_accuracy: 0.9347
# Epoch 65/200
# 10/10 [==============================] - 7s 642ms/step - loss: 0.1607 - accuracy: 0.9457 - val_loss: 0.1557 - val_accuracy: 0.9313
# Epoch 66/200
# 10/10 [==============================] - 6s 627ms/step - loss: 0.1742 - accuracy: 0.9233 - val_loss: 0.1575 - val_accuracy: 0.9381
# Epoch 67/200
# 10/10 [==============================] - 8s 759ms/step - loss: 0.1734 - accuracy: 0.9423 - val_loss: 0.1513 - val_accuracy: 0.9450
# Epoch 68/200
# 10/10 [==============================] - 7s 697ms/step - loss: 0.1709 - accuracy: 0.9397 - val_loss: 0.1486 - val_accuracy: 0.9381
# Epoch 69/200
# 10/10 [==============================] - 7s 663ms/step - loss: 0.1625 - accuracy: 0.9423 - val_loss: 0.1472 - val_accuracy: 0.9416
# Epoch 70/200
# 10/10 [==============================] - 8s 808ms/step - loss: 0.1552 - accuracy: 0.9466 - val_loss: 0.1468 - val_accuracy: 0.9381
# Epoch 71/200
# 10/10 [==============================] - 7s 671ms/step - loss: 0.1587 - accuracy: 0.9397 - val_loss: 0.1482 - val_accuracy: 0.9381
# Epoch 72/200
# 10/10 [==============================] - 7s 675ms/step - loss: 0.1532 - accuracy: 0.9466 - val_loss: 0.1455 - val_accuracy: 0.9416
# Epoch 73/200
# 10/10 [==============================] - 7s 666ms/step - loss: 0.1612 - accuracy: 0.9440 - val_loss: 0.1404 - val_accuracy: 0.9381
# Epoch 74/200
# 10/10 [==============================] - 7s 648ms/step - loss: 0.1706 - accuracy: 0.9552 - val_loss: 0.1389 - val_accuracy: 0.9450
# Epoch 75/200
# 10/10 [==============================] - 8s 810ms/step - loss: 0.1314 - accuracy: 0.9492 - val_loss: 0.1379 - val_accuracy: 0.9450
# Epoch 76/200
# 10/10 [==============================] - 7s 665ms/step - loss: 0.1391 - accuracy: 0.9509 - val_loss: 0.1344 - val_accuracy: 0.9450
# Epoch 77/200
# 10/10 [==============================] - 7s 662ms/step - loss: 0.1499 - accuracy: 0.9492 - val_loss: 0.1325 - val_accuracy: 0.9485
# Epoch 78/200
# 10/10 [==============================] - 8s 880ms/step - loss: 0.1381 - accuracy: 0.9518 - val_loss: 0.1277 - val_accuracy: 0.9485
# Epoch 79/200
# 10/10 [==============================] - 8s 801ms/step - loss: 0.1432 - accuracy: 0.9535 - val_loss: 0.1281 - val_accuracy: 0.9485
# Epoch 80/200
# 10/10 [==============================] - 6s 629ms/step - loss: 0.1467 - accuracy: 0.9432 - val_loss: 0.1354 - val_accuracy: 0.9519
# Epoch 81/200
# 10/10 [==============================] - 8s 814ms/step - loss: 0.1598 - accuracy: 0.9397 - val_loss: 0.1414 - val_accuracy: 0.9450
# Epoch 82/200
# 10/10 [==============================] - 7s 684ms/step - loss: 0.1165 - accuracy: 0.9621 - val_loss: 0.1310 - val_accuracy: 0.9485
# Epoch 83/200
# 10/10 [==============================] - 7s 648ms/step - loss: 0.1616 - accuracy: 0.9440 - val_loss: 0.1344 - val_accuracy: 0.9450
# Epoch 84/200
# 10/10 [==============================] - 8s 773ms/step - loss: 0.1184 - accuracy: 0.9543 - val_loss: 0.1359 - val_accuracy: 0.9519
# Epoch 85/200
# 10/10 [==============================] - 8s 769ms/step - loss: 0.1236 - accuracy: 0.9595 - val_loss: 0.1294 - val_accuracy: 0.9519
# Epoch 86/200
# 10/10 [==============================] - 7s 643ms/step - loss: 0.1322 - accuracy: 0.9561 - val_loss: 0.1268 - val_accuracy: 0.9519
# Epoch 87/200
# 10/10 [==============================] - 8s 881ms/step - loss: 0.1163 - accuracy: 0.9569 - val_loss: 0.1259 - val_accuracy: 0.9553
# Epoch 88/200
# 10/10 [==============================] - 7s 713ms/step - loss: 0.1232 - accuracy: 0.9604 - val_loss: 0.1257 - val_accuracy: 0.9519
# Epoch 89/200
# 10/10 [==============================] - 7s 646ms/step - loss: 0.1176 - accuracy: 0.9569 - val_loss: 0.1254 - val_accuracy: 0.9485
# Epoch 90/200
# 10/10 [==============================] - 8s 752ms/step - loss: 0.1424 - accuracy: 0.9440 - val_loss: 0.1316 - val_accuracy: 0.9416
# Epoch 91/200
# 10/10 [==============================] - 6s 692ms/step - loss: 0.1320 - accuracy: 0.9587 - val_loss: 0.1314 - val_accuracy: 0.9519
# Epoch 92/200
# 10/10 [==============================] - 8s 794ms/step - loss: 0.1242 - accuracy: 0.9569 - val_loss: 0.1273 - val_accuracy: 0.9519
# Epoch 93/200
# 10/10 [==============================] - 7s 651ms/step - loss: 0.1100 - accuracy: 0.9578 - val_loss: 0.1188 - val_accuracy: 0.9450
# Epoch 94/200
# 10/10 [==============================] - 6s 632ms/step - loss: 0.1117 - accuracy: 0.9595 - val_loss: 0.1198 - val_accuracy: 0.9485
# Epoch 95/200
# 10/10 [==============================] - 8s 765ms/step - loss: 0.1201 - accuracy: 0.9621 - val_loss: 0.1201 - val_accuracy: 0.9519
# Epoch 96/200
# 10/10 [==============================] - 8s 809ms/step - loss: 0.1113 - accuracy: 0.9604 - val_loss: 0.1215 - val_accuracy: 0.9519
# Epoch 97/200
# 10/10 [==============================] - 7s 713ms/step - loss: 0.1132 - accuracy: 0.9552 - val_loss: 0.1180 - val_accuracy: 0.9588
# Epoch 98/200
# 10/10 [==============================] - 8s 796ms/step - loss: 0.0985 - accuracy: 0.9664 - val_loss: 0.1187 - val_accuracy: 0.9553
# Epoch 99/200
# 10/10 [==============================] - 8s 772ms/step - loss: 0.1047 - accuracy: 0.9604 - val_loss: 0.1182 - val_accuracy: 0.9519
# Epoch 100/200
# 10/10 [==============================] - 7s 713ms/step - loss: 0.1047 - accuracy: 0.9630 - val_loss: 0.1179 - val_accuracy: 0.9519
# Epoch 101/200
# 10/10 [==============================] - 7s 670ms/step - loss: 0.0929 - accuracy: 0.9707 - val_loss: 0.1144 - val_accuracy: 0.9553
# Epoch 102/200
# 10/10 [==============================] - 7s 743ms/step - loss: 0.1159 - accuracy: 0.9604 - val_loss: 0.1114 - val_accuracy: 0.9519
# Epoch 103/200
# 10/10 [==============================] - 8s 809ms/step - loss: 0.0990 - accuracy: 0.9604 - val_loss: 0.1123 - val_accuracy: 0.9553
# Epoch 104/200
# 10/10 [==============================] - 7s 736ms/step - loss: 0.0846 - accuracy: 0.9690 - val_loss: 0.1188 - val_accuracy: 0.9553
# Epoch 105/200
# 10/10 [==============================] - 7s 634ms/step - loss: 0.0767 - accuracy: 0.9776 - val_loss: 0.1164 - val_accuracy: 0.9553
# Epoch 106/200
# 10/10 [==============================] - 8s 764ms/step - loss: 0.0726 - accuracy: 0.9733 - val_loss: 0.1136 - val_accuracy: 0.9553
# Epoch 107/200
# 10/10 [==============================] - 7s 672ms/step - loss: 0.0828 - accuracy: 0.9699 - val_loss: 0.1124 - val_accuracy: 0.9553
# Epoch 108/200
# 10/10 [==============================] - 8s 729ms/step - loss: 0.0959 - accuracy: 0.9638 - val_loss: 0.1133 - val_accuracy: 0.9553
# Epoch 109/200
# 10/10 [==============================] - 8s 786ms/step - loss: 0.0844 - accuracy: 0.9707 - val_loss: 0.1174 - val_accuracy: 0.9553
# Epoch 110/200
# 10/10 [==============================] - 7s 724ms/step - loss: 0.0762 - accuracy: 0.9699 - val_loss: 0.1125 - val_accuracy: 0.9553
# Epoch 111/200
# 10/10 [==============================] - 7s 676ms/step - loss: 0.0794 - accuracy: 0.9733 - val_loss: 0.1110 - val_accuracy: 0.9519
# Epoch 112/200
# 10/10 [==============================] - 8s 771ms/step - loss: 0.0892 - accuracy: 0.9733 - val_loss: 0.1117 - val_accuracy: 0.9553
# Epoch 113/200
# 10/10 [==============================] - 8s 781ms/step - loss: 0.0673 - accuracy: 0.9811 - val_loss: 0.1111 - val_accuracy: 0.9588
# Epoch 114/200
# 10/10 [==============================] - 6s 628ms/step - loss: 0.0713 - accuracy: 0.9707 - val_loss: 0.1218 - val_accuracy: 0.9553
# Epoch 115/200
# 10/10 [==============================] - 8s 851ms/step - loss: 0.0942 - accuracy: 0.9664 - val_loss: 0.1147 - val_accuracy: 0.9622
# Epoch 116/200
# 10/10 [==============================] - 7s 684ms/step - loss: 0.0863 - accuracy: 0.9716 - val_loss: 0.1152 - val_accuracy: 0.9519
# Epoch 117/200
# 10/10 [==============================] - 7s 637ms/step - loss: 0.0954 - accuracy: 0.9690 - val_loss: 0.1120 - val_accuracy: 0.9622
# Epoch 118/200
# 10/10 [==============================] - 6s 625ms/step - loss: 0.0689 - accuracy: 0.9802 - val_loss: 0.1139 - val_accuracy: 0.9588
# Epoch 119/200
# 10/10 [==============================] - 8s 772ms/step - loss: 0.0871 - accuracy: 0.9733 - val_loss: 0.1145 - val_accuracy: 0.9588
# Epoch 120/200
# 10/10 [==============================] - 6s 626ms/step - loss: 0.0719 - accuracy: 0.9733 - val_loss: 0.1143 - val_accuracy: 0.9553
# Epoch 121/200
# 10/10 [==============================] - 7s 662ms/step - loss: 0.1011 - accuracy: 0.9707 - val_loss: 0.1131 - val_accuracy: 0.9588
# Epoch 122/200
# 10/10 [==============================] - 7s 643ms/step - loss: 0.0944 - accuracy: 0.9733 - val_loss: 0.1153 - val_accuracy: 0.9588
# Epoch 123/200
# 10/10 [==============================] - 8s 815ms/step - loss: 0.0792 - accuracy: 0.9767 - val_loss: 0.1101 - val_accuracy: 0.9553
# Epoch 124/200
# 10/10 [==============================] - 6s 632ms/step - loss: 0.0672 - accuracy: 0.9759 - val_loss: 0.1105 - val_accuracy: 0.9553
# Epoch 125/200
# 10/10 [==============================] - 6s 633ms/step - loss: 0.1211 - accuracy: 0.9604 - val_loss: 0.1242 - val_accuracy: 0.9588
# Epoch 126/200
# 10/10 [==============================] - 8s 808ms/step - loss: 0.0937 - accuracy: 0.9673 - val_loss: 0.1179 - val_accuracy: 0.9588
# Epoch 127/200
# 10/10 [==============================] - 8s 754ms/step - loss: 0.0842 - accuracy: 0.9655 - val_loss: 0.1177 - val_accuracy: 0.9519
# Epoch 128/200
# 10/10 [==============================] - 6s 617ms/step - loss: 0.0610 - accuracy: 0.9811 - val_loss: 0.1204 - val_accuracy: 0.9553
# Epoch 129/200
# 10/10 [==============================] - 6s 616ms/step - loss: 0.0684 - accuracy: 0.9716 - val_loss: 0.1201 - val_accuracy: 0.9553
# Epoch 130/200
# 10/10 [==============================] - 7s 656ms/step - loss: 0.0759 - accuracy: 0.9681 - val_loss: 0.1180 - val_accuracy: 0.9553
# Epoch 131/200
# 10/10 [==============================] - 8s 762ms/step - loss: 0.0583 - accuracy: 0.9742 - val_loss: 0.1195 - val_accuracy: 0.9485
# Epoch 132/200
# 10/10 [==============================] - 6s 618ms/step - loss: 0.0598 - accuracy: 0.9785 - val_loss: 0.1327 - val_accuracy: 0.9485
# Epoch 133/200
# 10/10 [==============================] - 7s 623ms/step - loss: 0.0733 - accuracy: 0.9724 - val_loss: 0.1226 - val_accuracy: 0.9553
# Epoch 134/200
# 10/10 [==============================] - 8s 742ms/step - loss: 0.0904 - accuracy: 0.9724 - val_loss: 0.1169 - val_accuracy: 0.9485
# Epoch 135/200
# 10/10 [==============================] - 7s 673ms/step - loss: 0.0578 - accuracy: 0.9776 - val_loss: 0.1155 - val_accuracy: 0.9622
# Epoch 136/200
# 10/10 [==============================] - 8s 701ms/step - loss: 0.0635 - accuracy: 0.9776 - val_loss: 0.1153 - val_accuracy: 0.9622
# Epoch 137/200
# 10/10 [==============================] - 8s 752ms/step - loss: 0.0536 - accuracy: 0.9828 - val_loss: 0.1162 - val_accuracy: 0.9588
# Epoch 138/200
# 10/10 [==============================] - 6s 629ms/step - loss: 0.0525 - accuracy: 0.9811 - val_loss: 0.1180 - val_accuracy: 0.9588
# Epoch 139/200
# 10/10 [==============================] - 8s 856ms/step - loss: 0.0496 - accuracy: 0.9802 - val_loss: 0.1174 - val_accuracy: 0.9588
# Epoch 140/200
# 10/10 [==============================] - 7s 674ms/step - loss: 0.0579 - accuracy: 0.9836 - val_loss: 0.1145 - val_accuracy: 0.9656
# Epoch 141/200
# 10/10 [==============================] - 8s 763ms/step - loss: 0.0440 - accuracy: 0.9862 - val_loss: 0.1120 - val_accuracy: 0.9622
# Epoch 142/200
# 10/10 [==============================] - 7s 748ms/step - loss: 0.0616 - accuracy: 0.9750 - val_loss: 0.1052 - val_accuracy: 0.9588
# Epoch 143/200
# 10/10 [==============================] - 7s 640ms/step - loss: 0.0455 - accuracy: 0.9836 - val_loss: 0.1030 - val_accuracy: 0.9622
# Epoch 144/200
# 10/10 [==============================] - 7s 638ms/step - loss: 0.0684 - accuracy: 0.9767 - val_loss: 0.1007 - val_accuracy: 0.9622
# Epoch 145/200
# 10/10 [==============================] - 8s 772ms/step - loss: 0.0504 - accuracy: 0.9811 - val_loss: 0.1009 - val_accuracy: 0.9622
# Epoch 146/200
# 10/10 [==============================] - 7s 730ms/step - loss: 0.0616 - accuracy: 0.9785 - val_loss: 0.1005 - val_accuracy: 0.9622
# Epoch 147/200
# 10/10 [==============================] - 7s 623ms/step - loss: 0.0538 - accuracy: 0.9785 - val_loss: 0.1049 - val_accuracy: 0.9622
# Epoch 148/200
# 10/10 [==============================] - 8s 808ms/step - loss: 0.0553 - accuracy: 0.9793 - val_loss: 0.1044 - val_accuracy: 0.9622
# Epoch 149/200
# 10/10 [==============================] - 7s 686ms/step - loss: 0.0730 - accuracy: 0.9733 - val_loss: 0.1143 - val_accuracy: 0.9622
# Epoch 150/200
# 10/10 [==============================] - 8s 772ms/step - loss: 0.0740 - accuracy: 0.9716 - val_loss: 0.1020 - val_accuracy: 0.9622
# Epoch 151/200
# 10/10 [==============================] - 7s 718ms/step - loss: 0.0591 - accuracy: 0.9836 - val_loss: 0.1023 - val_accuracy: 0.9588
# Epoch 152/200
# 10/10 [==============================] - 7s 669ms/step - loss: 0.0546 - accuracy: 0.9836 - val_loss: 0.1003 - val_accuracy: 0.9656
# Epoch 153/200
# 10/10 [==============================] - 7s 664ms/step - loss: 0.0474 - accuracy: 0.9819 - val_loss: 0.0965 - val_accuracy: 0.9656
# Epoch 154/200
# 10/10 [==============================] - 8s 813ms/step - loss: 0.0696 - accuracy: 0.9871 - val_loss: 0.0946 - val_accuracy: 0.9656
# Epoch 155/200
# 10/10 [==============================] - 6s 625ms/step - loss: 0.0505 - accuracy: 0.9802 - val_loss: 0.0955 - val_accuracy: 0.9656
# Epoch 156/200
# 10/10 [==============================] - 8s 784ms/step - loss: 0.0488 - accuracy: 0.9828 - val_loss: 0.0972 - val_accuracy: 0.9622
# Epoch 157/200
# 10/10 [==============================] - 7s 659ms/step - loss: 0.0491 - accuracy: 0.9793 - val_loss: 0.0877 - val_accuracy: 0.9656
# Epoch 158/200
# 10/10 [==============================] - 7s 640ms/step - loss: 0.0440 - accuracy: 0.9871 - val_loss: 0.0890 - val_accuracy: 0.9691
# Epoch 159/200
# 10/10 [==============================] - 8s 855ms/step - loss: 0.0422 - accuracy: 0.9854 - val_loss: 0.0888 - val_accuracy: 0.9725
# Epoch 160/200
# 10/10 [==============================] - 7s 648ms/step - loss: 0.0539 - accuracy: 0.9819 - val_loss: 0.0907 - val_accuracy: 0.9691
# Epoch 161/200
# 10/10 [==============================] - 7s 671ms/step - loss: 0.0371 - accuracy: 0.9854 - val_loss: 0.0932 - val_accuracy: 0.9656
# Epoch 162/200
# 10/10 [==============================] - 8s 774ms/step - loss: 0.0553 - accuracy: 0.9819 - val_loss: 0.1051 - val_accuracy: 0.9656
# Epoch 163/200
# 10/10 [==============================] - 6s 707ms/step - loss: 0.0707 - accuracy: 0.9742 - val_loss: 0.1009 - val_accuracy: 0.9656
# Epoch 164/200
# 10/10 [==============================] - 8s 716ms/step - loss: 0.0590 - accuracy: 0.9811 - val_loss: 0.0930 - val_accuracy: 0.9656
# Epoch 165/200
# 10/10 [==============================] - 8s 763ms/step - loss: 0.0446 - accuracy: 0.9862 - val_loss: 0.0890 - val_accuracy: 0.9656
# Epoch 166/200
# 10/10 [==============================] - 7s 669ms/step - loss: 0.0399 - accuracy: 0.9871 - val_loss: 0.0868 - val_accuracy: 0.9656
# Epoch 167/200
# 10/10 [==============================] - 7s 669ms/step - loss: 0.0503 - accuracy: 0.9836 - val_loss: 0.0929 - val_accuracy: 0.9656
# Epoch 168/200
# 10/10 [==============================] - 8s 775ms/step - loss: 0.0441 - accuracy: 0.9828 - val_loss: 0.0858 - val_accuracy: 0.9656
# Epoch 169/200
# 10/10 [==============================] - 8s 771ms/step - loss: 0.0400 - accuracy: 0.9854 - val_loss: 0.0829 - val_accuracy: 0.9656
# Epoch 170/200
# 10/10 [==============================] - 6s 625ms/step - loss: 0.0405 - accuracy: 0.9854 - val_loss: 0.0971 - val_accuracy: 0.9691
# Epoch 171/200
# 10/10 [==============================] - 7s 669ms/step - loss: 0.0429 - accuracy: 0.9871 - val_loss: 0.0835 - val_accuracy: 0.9656
# Epoch 172/200
# 10/10 [==============================] - 8s 777ms/step - loss: 0.0525 - accuracy: 0.9750 - val_loss: 0.1106 - val_accuracy: 0.9485
# Epoch 173/200
# 10/10 [==============================] - 7s 645ms/step - loss: 0.0646 - accuracy: 0.9724 - val_loss: 0.1001 - val_accuracy: 0.9622
# Epoch 174/200
# 10/10 [==============================] - 7s 685ms/step - loss: 0.0502 - accuracy: 0.9811 - val_loss: 0.0938 - val_accuracy: 0.9656
# Epoch 175/200
# 10/10 [==============================] - 8s 806ms/step - loss: 0.0599 - accuracy: 0.9793 - val_loss: 0.0925 - val_accuracy: 0.9622
# Epoch 176/200
# 10/10 [==============================] - 8s 803ms/step - loss: 0.0588 - accuracy: 0.9776 - val_loss: 0.0939 - val_accuracy: 0.9622
# Epoch 177/200
# 10/10 [==============================] - 7s 666ms/step - loss: 0.0352 - accuracy: 0.9914 - val_loss: 0.0911 - val_accuracy: 0.9622
# Epoch 178/200
# 10/10 [==============================] - 7s 648ms/step - loss: 0.0414 - accuracy: 0.9888 - val_loss: 0.0875 - val_accuracy: 0.9553
# Epoch 179/200
# 10/10 [==============================] - 8s 798ms/step - loss: 0.0353 - accuracy: 0.9862 - val_loss: 0.0859 - val_accuracy: 0.9588
# Epoch 180/200
# 10/10 [==============================] - 6s 627ms/step - loss: 0.0261 - accuracy: 0.9914 - val_loss: 0.0833 - val_accuracy: 0.9622
# Epoch 181/200
# 10/10 [==============================] - 8s 810ms/step - loss: 0.0267 - accuracy: 0.9905 - val_loss: 0.0824 - val_accuracy: 0.9691
# Epoch 182/200
# 10/10 [==============================] - 7s 679ms/step - loss: 0.0402 - accuracy: 0.9871 - val_loss: 0.0831 - val_accuracy: 0.9588
# Epoch 183/200
# 10/10 [==============================] - 7s 753ms/step - loss: 0.0423 - accuracy: 0.9862 - val_loss: 0.0885 - val_accuracy: 0.9588
# Epoch 184/200
# 10/10 [==============================] - 7s 644ms/step - loss: 0.0371 - accuracy: 0.9879 - val_loss: 0.0886 - val_accuracy: 0.9622
# Epoch 185/200
# 10/10 [==============================] - 8s 816ms/step - loss: 0.0345 - accuracy: 0.9922 - val_loss: 0.0930 - val_accuracy: 0.9622
# Epoch 186/200
# 10/10 [==============================] - 7s 730ms/step - loss: 0.0358 - accuracy: 0.9879 - val_loss: 0.0909 - val_accuracy: 0.9622
# Epoch 187/200
# 10/10 [==============================] - 7s 793ms/step - loss: 0.0257 - accuracy: 0.9905 - val_loss: 0.0849 - val_accuracy: 0.9656
# Epoch 188/200
# 10/10 [==============================] - 8s 890ms/step - loss: 0.0297 - accuracy: 0.9914 - val_loss: 0.0829 - val_accuracy: 0.9656
# Epoch 189/200
# 10/10 [==============================] - 6s 631ms/step - loss: 0.0262 - accuracy: 0.9897 - val_loss: 0.0950 - val_accuracy: 0.9656
# Epoch 190/200
# 10/10 [==============================] - 8s 731ms/step - loss: 0.0405 - accuracy: 0.9845 - val_loss: 0.1039 - val_accuracy: 0.9622
# Epoch 191/200
# 10/10 [==============================] - 7s 785ms/step - loss: 0.0410 - accuracy: 0.9836 - val_loss: 0.0919 - val_accuracy: 0.9691
# Epoch 192/200
#  8/10 [=======================>......] - ETA: 1s - loss: 0.0591 - accuracy: 0.9768

# %%
figure = plt.figure(figsize=(10, 10))
plt.plot(hist.history['accuracy'], label='Train_accuracy')
plt.plot(hist.history['val_accuracy'], label='Test_accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(loc="upper left")
plt.show()

figure2 = plt.figure(figsize=(10, 10))
plt.plot(hist.history['loss'], label='Train_loss')
plt.plot(hist.history['val_loss'], label='Test_loss')
plt.title('Model Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(loc="upper left")
plt.show()

# %%
pred = model.evaluate(X_test, Y_test)
print(f'Test Set Accuracy: {pred[1]}')
print(f'Test Set Loss: {pred[0]}')
# Out:
# 10/10 [==============================] - 0s 35ms/step - loss: 0.0769 - accuracy: 0.9759
# Test Set Accuracy: 0.975944995880127
# Test Set Loss: 0.0768781378865242

# %%
ypred = model.predict(X_test)
ypred = np.argmax(ypred, axis=1)
Y_test_pred = np.argmax(Y_test, axis=1)
print(classification_report(Y_test_pred, ypred))
# Out:
# 10/10 [==============================] - 0s 36ms/step
#               precision    recall  f1-score   support
#
#            0       0.98      0.97      0.98       146
#            1       0.97      0.98      0.98       145
#
#     accuracy                           0.98       291
#    macro avg       0.98      0.98      0.98       291
# weighted avg       0.98      0.98      0.98       291

# %%
matrix = confusion_matrix(Y_test_pred, ypred)
df_cm = pd.DataFrame(matrix, index=[0, 1], columns=[0, 1])
figure = plt.figure(figsize=(5, 5))
sns.heatmap(df_cm, annot=True, fmt='d')
# Out:
# <Axes: >

# %%
model.save('Driver_Drowsiness_Detection.h5')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
labels = ['Closed', 'Open']
img_closed1 = cv2.imread('driver_drowsiness_detection/closed_eye.jpg')
img_closed2 = cv2.imread('driver_drowsiness_detection/closed_eye2.jpg')
img_open1 = cv2.imread('driver_drowsiness_detection/open_eye.jpg')
img_open2 = cv2.imread('driver_drowsiness_detection/open_eye2.jpg')

img_closed1 = cv2.resize(img_closed1, (32, 32))
img_closed2 = cv2.resize(img_closed2, (32, 32))
img_open1 = cv2.resize(img_open1, (32, 32))
img_open2 = cv2.resize(img_open2, (32, 32))

img_closed1 = np.array(img_closed1)
img_closed2 = np.array(img_closed2)
img_open1 = np.array(img_open1)
img_open2 = np.array(img_open2)

img_closed1 = np.expand_dims(img_closed1, axis=0)
img_closed2 = np.expand_dims(img_closed2, axis=0)
img_open1 = np.expand_dims(img_open1, axis=0)
img_open2 = np.expand_dims(img_open2, axis=0)

# %%
ypred_closed1 = model.predict(img_closed1)
ypred_closed2 = model.predict(img_closed2)
ypred_open1 = model.predict(img_open1)
ypred_open2 = model.predict(img_open2)
# Out:
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 22ms/step

# %%
figure = plt.figure(figsize=(2, 2))
img_closed1 = np.squeeze(img_closed1, axis=0)
plt.imshow(img_closed1)
plt.axis('off')
plt.title(f'Prediction by the model: {labels[np.argmax(ypred_closed1[0], axis=0)]}')
plt.show()

# %%
figure = plt.figure(figsize=(2, 2))
img_closed2 = np.squeeze(img_closed2, axis=0)
plt.imshow(img_closed2)
plt.axis('off')
plt.title(f'Prediction by the model: {labels[np.argmax(ypred_closed2[0], axis=0)]}')
plt.show()

# %%
figure = plt.figure(figsize=(2, 2))
img_open1 = np.squeeze(img_open1, axis=0)
plt.imshow(img_open1)
plt.axis('off')
plt.title(f'Prediction by the model: {labels[np.argmax(ypred_open1[0], axis=0)]}')
plt.show()

# %%
figure = plt.figure(figsize=(2, 2))
img_open2 = np.squeeze(img_open2, axis=0)
plt.imshow(img_open2)
plt.axis('off')
plt.title(f'Prediction by the model: {labels[np.argmax(ypred_open2[0], axis=0)]}')
plt.show()

# %%
import cv2
import numpy as np
from keras.models import load_model
import time
import pygame

# Load the trained model
model = load_model('Driver_Drowsiness_Detection.h5')

# Initialize pygame for sound alert
pygame.mixer.init()

# Load the cascade classifiers for face and eye detection
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
eye_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_eye.xml')

# Function to detect drowsiness
def detect_drowsiness(frame, model):
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray, 1.1, 4)

    for (x, y, w, h) in faces:
        roi_gray = gray[y:y+h, x:x+w]
        roi_color = frame[y:y+h, x:x+w]
        eyes = eye_cascade.detectMultiScale(roi_gray)

        for (ex, ey, ew, eh) in eyes:
            eye_roi = roi_color[ey:ey + eh, ex:ex + ew]
            eye_roi_color = cv2.cvtColor(eye_roi, cv2.COLOR_BGR2RGB)  # Convert grayscale to color
            resized = cv2.resize(eye_roi_color, (32, 32))  # Resize the image to (32, 32)
            normalized = resized / 255.0
            reshaped = np.reshape(normalized, (-1, 32, 32, 3))  # Reshape to match model input shape
            result = model.predict(reshaped)
            print("Result",result[0][1])
            if result[0][1] > 0.01:
                return False

    return True


# Main function
def main():
    cap = cv2.VideoCapture(0)

    start_time = None
    alert_start_time = None
    alert_triggered = False

    while True:
        ret, frame = cap.read()
        if not ret:
            break

        if detect_drowsiness(frame, model):
            if start_time is None:
                start_time = time.time()
            else:
                elapsed_time = time.time() - start_time
                if elapsed_time > 3 and not alert_triggered:
                    alert_start_time = time.time()
                    pygame.mixer.music.load('alert_sound1.mp3')  # Load alert sound
                    pygame.mixer.music.play(-1)  # Play alert sound in a loop
                    alert_triggered = True
                elif elapsed_time > 2:
                    start_time = None
                    alert_triggered = False
        else:
            start_time = None
            alert_triggered = False

            if alert_start_time is not None:
                elapsed_time = time.time() - alert_start_time
                if elapsed_time > 2:
                    pygame.mixer.music.stop()  # Stop playing alert sound
                    alert_start_time = None

        cv2.putText(frame, f"State: {'Drowsy' if alert_triggered else 'Alert'}", (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 255, 0), 2)
        cv2.imshow('Drowsiness Detection', frame)

        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

    cap.release()
    cv2.destroyAllWindows()

if __name__ == "__main__":
    main()
